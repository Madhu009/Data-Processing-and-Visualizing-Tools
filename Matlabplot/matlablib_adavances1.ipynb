# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 20, 1000)
y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x,y1,color="g",label="sine")
plt.plot(x,y2,color="b",label="cosine")
plt.legend(loc="upper right")
plt.xlabel("values from 0 to 20")
plt.ylabel("values from -1 to 1")
plt.ylim(-1.5,2)

plt.annotate('local max', xy=(1.5, 1), xytext=(5, 1.5),
            arrowprops=dict(facecolor='black', shrink=0.15),
            ) #used for anotation 
plt.show()

# %%
plt.figure(1)
plt.subplot(221)# 2 rows 2 colmns figure 1
plt.plot(x,y1,"g",x,y2,"k")

plt.subplot(222)
plt.plot(x,y1,"g",x,y2,"k")

plt.subplot(223)
plt.plot(x,y1,"g",x,y2,"k")

plt.subplot(224)
plt.plot(x,y1,"g",x,y2,"k")

plt.show()
